# %%
import os
os.chdir(os.path.join(os.getcwd(),'..'))

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
stage_in = lambda x: x[6:7]
age_in = lambda x: int(x[-2:])

# %%
from services import DataReader

X, y = DataReader().read_analyze_solution('bc_averaging_disease_analysis#k=0')

# %%
_, y = DataReader().read_data('BC', True)

# %%
import numpy as np
from itertools import groupby

freq = {key:len(list(group)) for key, group in groupby(np.sort(y))}

freq
# Out:
# {'1': 19, '2': 50, '3': 49, '4': 20, 'h': 76}

# %%
from preprocessing import DynamicPreprocessing

# pre = DynamicPreprocessing(['flux-diff', 'feature-selection','pathway-scoring', 'transport-elimination'])
pre = DynamicPreprocessing(['flux-diff', 'pathway-scoring', 'transport-elimination'])
X_pre = pre.fit_transform(X, y)

# %%
from sklearn.feature_selection import f_classif, VarianceThreshold
from sklearn.feature_extraction import DictVectorizer
from preprocessing import *

X_not_h, y_not_h = list(zip(*filter(lambda x: x[1] != 'h', zip(X_pre, y))))

vect = DictVectorizer()
vt = VarianceThreshold(0.1)
inv_vect = InverseDictVectorizer(vect, vt)

X_not_h_vect = vt.fit_transform(vect.fit_transform(X_not_h), y_not_h)

X_not_h = inv_vect.fit_transform(X_not_h_vect.todense()) 

(F_not, pval_not) = f_classif(X_not_h_vect, y_not_h)

# %%
df_not_h = pd.DataFrame().from_records(X_not_h)

df_not_h['categories'] = y_not_h
df_not_h = df_not_h.groupby('categories').mean().T

df_not_h['F_val'] = F_not
df_not_h['p_val'] = pval_not

# %%
df_not_h.sort_values('F_val', ascending=False).round(5)
# Out:
# categories                                                  1          2  \
# Folate metabolism_dif                                97.26772   -5.75032
# Purine synthesis_dif                                 73.21196 -265.41458
# Biotin metabolism_dif                              -343.64054  122.21527
# Urea cycle_dif                                       48.91754  -12.04996
# Lysine metabolism_dif                               -82.99751    1.50123
# Fatty acid oxidation_dif                            -11.06338    5.37158
# Methionine and cysteine metabolism_dif              259.07399  194.27210
# Cholesterol metabolism_dif                           -1.65167   24.88466
# Glycosphingolipid metabolism_dif                      2.94552   -0.20641
# Glycine, serine, alanine and threonine metaboli...    4.89783 -109.64664
# beta-Alanine metabolism_dif                         -70.38507   15.82948
# Propanoate metabolism_dif                           -25.65627   23.82920
# CoA catabolism_dif                                  434.12457  659.54300
# Triacylglycerol synthesis_dif                         3.24320  -21.17575
# Glycerophospholipid metabolism_dif                  -29.16620  -46.84334
# Butanoate metabolism_dif                            -87.82865  -87.82865
# Oxidative phosphorylation_dif                       108.76928   29.84547
# Heme synthesis_dif                                    2.36591    2.18136
# Galactose metabolism_dif                           -113.19929  -80.09673
# Miscellaneous_dif                                     2.72502   12.12756
# Ubiquinone synthesis_dif                            -12.14525  -20.19949
# Vitamin D metabolism_dif                             -0.72492   -0.58045
# Phosphatidylinositol phosphate metabolism_dif        -3.06762   -7.40393
# Vitamin C metabolism_dif                             -8.63487   -1.11920
# Starch and sucrose metabolism_dif                    19.19957   10.82012
# Nucleotide salvage pathway_dif                        1.79936   -9.53096
# Pyruvate metabolism_dif                            -240.23101 -158.48998
# Glutathione metabolism_dif                           75.56817   57.10407
# Valine, leucine, and isoleucine metabolism_dif      -67.03547   20.98753
# Cysteine Metabolism_dif                              12.56092  -37.45829
# Nucleotide interconversion_dif                       54.10125   35.61396
# Citric acid cycle_dif                                83.07708  108.89757
# Glycolysis/gluconeogenesis_dif                       41.41659   -6.89395
# CoA synthesis_dif                                    42.57950   75.31866
# Glyoxylate and dicarboxylate metabolism_dif         -78.81819  -73.00012
# NAD metabolism_dif                                    3.00770   13.08844
# Alanine and aspartate metabolism_dif                 81.27259  217.29687
# Fatty acid synthesis_dif                             53.60378   44.35560
# Squalene and cholesterol synthesis_dif             -168.90861 -225.96678
# Taurine and hypotaurine metabolism_dif              992.38268  934.48611
# Glutamate metabolism_dif                            -58.16983  -89.53838
# Pyrimidine synthesis_dif                            -18.63628  -20.55067
# Thiamine metabolism_dif                              -0.00000    1.40496
# Bile acid synthesis_dif                              27.42699   24.32021
# Tyrosine metabolism_dif                              -2.27908   -2.40432
# Inositol phosphate metabolism_dif                    -8.80272   -9.46774
# Tryptophan metabolism_dif                             6.91925    4.37957
# Purine catabolism_dif                               -50.67870  -48.01306
# N-glycan degradation_dif                             -4.07630   -3.52418
# N-glycan synthesis_dif                               -5.52866   -4.84703
# Arginine and Proline Metabolism_dif                  67.01943   63.40973
# Steroid metabolism_dif                               -0.79542    0.25722
# Hyaluronan metabolism_dif                          -151.56604 -126.93196
# Eicosanoid metabolism_dif                            11.03660   10.31753
# ROS detoxification_dif                              -73.03889  -32.68743
# Aminosugar metabolism_dif                           -43.97508  -52.63256
# Vitamin A metabolism_dif                              0.80726    2.83443
# Pentose phosphate pathway_dif                      -157.11803 -161.22102
# Sphingolipid metabolism_dif                         -25.46385  -19.29018
# Pyrimidine catabolism_dif                           -10.75527   -8.20730
# Fructose and mannose metabolism_dif                   4.13744    3.73991
# R group synthesis_dif                               -44.42797  -47.98091
#
# categories                                                  3          4  \
# Folate metabolism_dif                                -6.94192   36.09383
# Purine synthesis_dif                               -248.33103 -209.76979
# Biotin metabolism_dif                                14.49492 -159.43001
# Urea cycle_dif                                      -27.60176  -49.98541
# Lysine metabolism_dif                               149.36872  109.81435
# Fatty acid oxidation_dif                              4.61886   -0.29429
# Methionine and cysteine metabolism_dif              165.42633  188.10838
# Cholesterol metabolism_dif                            0.40005   24.80781
# Glycosphingolipid metabolism_dif                     -0.57110   -0.72626
# Glycine, serine, alanine and threonine metaboli... -101.28245 -105.98522
# beta-Alanine metabolism_dif                          69.10188  -60.29735
# Propanoate metabolism_dif                            -5.22948   27.29543
# CoA catabolism_dif                                  574.19428  462.82998
# Triacylglycerol synthesis_dif                       -35.87449   36.26484
# Glycerophospholipid metabolism_dif                  -61.71692  -37.79724
# Butanoate metabolism_dif                            -87.82865  -64.12682
# Oxidative phosphorylation_dif                        38.69091  -16.15620
# Heme synthesis_dif                                   -1.22261    7.46080
# Galactose metabolism_dif                            -40.39592 -123.12857
# Miscellaneous_dif                                     0.90877    5.12362
# Ubiquinone synthesis_dif                             -5.50808  -25.46683
# Vitamin D metabolism_dif                             -0.98419    0.95547
# Phosphatidylinositol phosphate metabolism_dif        -9.44535   -4.23430
# Vitamin C metabolism_dif                            -13.56908  -13.56908
# Starch and sucrose metabolism_dif                    20.38280   -2.26424
# Nucleotide salvage pathway_dif                       -6.48921   35.64992
# Pyruvate metabolism_dif                            -167.39724 -124.26902
# Glutathione metabolism_dif                           54.97400   13.49305
# Valine, leucine, and isoleucine metabolism_dif        8.91345  -22.59604
# Cysteine Metabolism_dif                             -47.86232  -56.53195
# Nucleotide interconversion_dif                       23.74051   31.21613
# Citric acid cycle_dif                               148.88458   24.55694
# Glycolysis/gluconeogenesis_dif                       -0.31234   -2.53310
# CoA synthesis_dif                                    58.44442   37.43428
# Glyoxylate and dicarboxylate metabolism_dif        -163.16455  -66.05532
# NAD metabolism_dif                                  -37.31194  -15.76399
# Alanine and aspartate metabolism_dif                179.34845  146.33993
# Fatty acid synthesis_dif                             27.22299   30.67732
# Squalene and cholesterol synthesis_dif             -127.31120 -207.54594
# Taurine and hypotaurine metabolism_dif              942.30975  806.17664
# Glutamate metabolism_dif                            -84.42057  -65.21670
# Pyrimidine synthesis_dif                            -50.64779  -43.95020
# Thiamine metabolism_dif                               8.40276    0.00000
# Bile acid synthesis_dif                              20.92564   15.27725
# Tyrosine metabolism_dif                              -2.77064   -2.96966
# Inositol phosphate metabolism_dif                   -11.82830  -11.37229
# Tryptophan metabolism_dif                             2.58931   -4.55926
# Purine catabolism_dif                               -61.51350  -44.53427
# N-glycan degradation_dif                             -2.36293   -4.07630
# N-glycan synthesis_dif                               -3.49800   -5.52866
# Arginine and Proline Metabolism_dif                  49.95996   44.29943
# Steroid metabolism_dif                               -0.25836   -0.79542
# Hyaluronan metabolism_dif                          -131.45738 -162.25681
# Eicosanoid metabolism_dif                             3.96467    5.30098
# ROS detoxification_dif                              -39.77572  -95.20271
# Aminosugar metabolism_dif                           -50.66363  -59.16148
# Vitamin A metabolism_dif                              0.51187   -2.49107
# Pentose phosphate pathway_dif                      -189.00715 -161.32849
# Sphingolipid metabolism_dif                         -18.59004  -19.68865
# Pyrimidine catabolism_dif                           -17.81522   -9.45356
# Fructose and mannose metabolism_dif                   3.50412    4.13744
# R group synthesis_dif                               -67.11949  -63.65837
#
# categories                                             F_val    p_val
# Folate metabolism_dif                               11.35930  0.00000
# Purine synthesis_dif                                 7.07628  0.00019
# Biotin metabolism_dif                                3.69895  0.01346
# Urea cycle_dif                                       3.24106  0.02418
# Lysine metabolism_dif                                3.09615  0.02911
# Fatty acid oxidation_dif                             2.81018  0.04194
# Methionine and cysteine metabolism_dif               2.74608  0.04551
# Cholesterol metabolism_dif                           2.71200  0.04753
# Glycosphingolipid metabolism_dif                     2.66907  0.05020
# Glycine, serine, alanine and threonine metaboli...   2.51428  0.06112
# beta-Alanine metabolism_dif                          2.49506  0.06263
# Propanoate metabolism_dif                            2.13699  0.09851
# CoA catabolism_dif                                   2.13611  0.09862
# Triacylglycerol synthesis_dif                        2.12655  0.09982
# Glycerophospholipid metabolism_dif                   2.12616  0.09987
# Butanoate metabolism_dif                             2.01017  0.11554
# Oxidative phosphorylation_dif                        1.59757  0.19296
# Heme synthesis_dif                                   1.53180  0.20918
# Galactose metabolism_dif                             1.41544  0.24107
# Miscellaneous_dif                                    1.37806  0.25224
# Ubiquinone synthesis_dif                             1.36608  0.25593
# Vitamin D metabolism_dif                             1.32839  0.26784
# Phosphatidylinositol phosphate metabolism_dif        1.31116  0.27345
# Vitamin C metabolism_dif                             1.23936  0.29803
# Starch and sucrose metabolism_dif                    1.17776  0.32070
# Nucleotide salvage pathway_dif                       1.13408  0.33771
# Pyruvate metabolism_dif                              1.04738  0.37388
# Glutathione metabolism_dif                           1.04050  0.37689
# Valine, leucine, and isoleucine metabolism_dif       1.01039  0.39031
# Cysteine Metabolism_dif                              0.99383  0.39787
# Nucleotide interconversion_dif                       0.95478  0.41620
# Citric acid cycle_dif                                0.91183  0.43718
# Glycolysis/gluconeogenesis_dif                       0.89024  0.44805
# CoA synthesis_dif                                    0.86690  0.46006
# Glyoxylate and dicarboxylate metabolism_dif          0.85446  0.46657
# NAD metabolism_dif                                   0.63630  0.59289
# Alanine and aspartate metabolism_dif                 0.61491  0.60650
# Fatty acid synthesis_dif                             0.60526  0.61270
# Squalene and cholesterol synthesis_dif               0.59607  0.61864
# Taurine and hypotaurine metabolism_dif               0.57361  0.63333
# Glutamate metabolism_dif                             0.56478  0.63917
# Pyrimidine synthesis_dif                             0.54207  0.65431
# Thiamine metabolism_dif                              0.49005  0.68977
# Bile acid synthesis_dif                              0.47320  0.70146
# Tyrosine metabolism_dif                              0.46523  0.70703
# Inositol phosphate metabolism_dif                    0.45318  0.71548
# Tryptophan metabolism_dif                            0.42605  0.73464
# Purine catabolism_dif                                0.40802  0.74749
# N-glycan degradation_dif                             0.40222  0.75163
# N-glycan synthesis_dif                               0.39559  0.75638
# Arginine and Proline Metabolism_dif                  0.37843  0.76870
# Steroid metabolism_dif                               0.35727  0.78395
# Hyaluronan metabolism_dif                            0.34986  0.78931
# Eicosanoid metabolism_dif                            0.31820  0.81220
# ROS detoxification_dif                               0.31786  0.81244
# Aminosugar metabolism_dif                            0.31691  0.81313
# Vitamin A metabolism_dif                             0.26932  0.84743
# Pentose phosphate pathway_dif                        0.18088  0.90922
# Sphingolipid metabolism_dif                          0.16583  0.91924
# Pyrimidine catabolism_dif                            0.11211  0.95289
# Fructose and mannose metabolism_dif                  0.08020  0.97066
# R group synthesis_dif                                0.06077  0.98031

# %%
df_not_h[(df_not_h['p_val'] <= 0.05)].sort_values('F_val', ascending=False)
# Out:
# categories                                       1           2           3  \
# Folate metabolism_dif                    97.267722   -5.750319   -6.941918
# Purine synthesis_dif                     73.211962 -265.414585 -248.331031
# Biotin metabolism_dif                  -343.640537  122.215265   14.494916
# Urea cycle_dif                           48.917538  -12.049964  -27.601756
# Lysine metabolism_dif                   -82.997512    1.501234  149.368720
# Fatty acid oxidation_dif                -11.063382    5.371577    4.618862
# Methionine and cysteine metabolism_dif  259.073988  194.272105  165.426327
# Cholesterol metabolism_dif               -1.651666   24.884659    0.400050
#
# categories                                       4      F_val     p_val
# Folate metabolism_dif                    36.093834  11.359299  0.000001
# Purine synthesis_dif                   -209.769792   7.076281  0.000189
# Biotin metabolism_dif                  -159.430011   3.698948  0.013460
# Urea cycle_dif                          -49.985411   3.241061  0.024183
# Lysine metabolism_dif                   109.814351   3.096153  0.029107
# Fatty acid oxidation_dif                 -0.294287   2.810178  0.041937
# Methionine and cysteine metabolism_dif  188.108378   2.746081  0.045508
# Cholesterol metabolism_dif               24.807814   2.711995  0.047528

# %%
df_not_h[(df_not_h['p_val'] <= 0.05)][['1','2','3','4']].T.plot(kind='line', figsize=(10, 10))
