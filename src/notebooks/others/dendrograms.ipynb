# %%
import os
os.chdir(os.path.join(os.getcwd(),'../..'))

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# %%
from services import DataReader

X, y = DataReader().read_analyze_solution('bc_averaging_disease_analysis#k=0')

# %%
from preprocessing import DynamicPreprocessing

pre = DynamicPreprocessing(['flux-diff', 'feature-selection', 'pathway-scoring', 'transport-elimination'])
X_pre = pre.fit_transform(X, y)

# %%
from visualization import HeatmapVisualization

heat = HeatmapVisualization(X_pre, y).iplot_heatmap()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="1e26577e-f92e-49bb-9cc2-58c64d056001" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1e26577e-f92e-49bb-9cc2-58c64d056001", [{"x": ["bc_125", "bc_127", "bc_101", "bc_159", "bc_140", "bc_163", "bc_113", "bc_168", "bc_14", "bc_135", "bc_149", "bc_156", "bc_93", "bc_136", "bc_126", "bc_31", "bc_164", "bc_88", "bc_121", "h_174", "bc_87", "bc_112", "bc_118", "bc_12", "bc_131", "h_181", "bc_21", "bc_141", "bc_4", "bc_148", "bc_150", "h_175", "h_178", "bc_102", "bc_152", "bc_89", "h_206", "bc_86", "bc_75", "bc_85", "bc_32", "bc_24", "bc_147", "bc_151", "bc_107", "bc_111", "bc_133", "bc_76", "bc_81", "bc_134", "bc_91", "bc_132", "bc_143", "bc_9", "bc_167", "bc_16", "bc_104", "bc_70", "bc_166", "bc_15", "bc_90", "bc_114", "bc_117", "bc_165", "bc_95", "bc_99", "bc_33", "bc_79", "h_47", "bc_120", "bc_139", "h_64", "h_68", "bc_77", "h_202", "bc_28", "bc_30", "h_203", "bc_71", "bc_2", "h_55", "h_173", "h_53", "h_42", "h_43", "bc_171", "bc_6", "h_177", "bc_96", "bc_108", "bc_25", "bc_110", "bc_145", "bc_160", "bc_20", "bc_92", "bc_17", "bc_142", "h_49", "bc_122", "bc_158", "bc_153", "bc_26", "bc_119", "bc_94", "bc_106", "bc_83", "bc_105", "bc_128", "bc_130", "bc_19", "bc_123", "bc_169", "bc_18", "bc_72", "bc_22", "bc_74", "bc_84", "bc_129", "bc_162", "bc_116", "bc_172", "bc_124", "bc_144", "bc_170", "h_54", "bc_146", "bc_109", "bc_154", "bc_82", "bc_7", "bc_23", "bc_0", "bc_73", "bc_155", "bc_8", "bc_78", "bc_80", "bc_137", "bc_3", "bc_10", "bc_103", "bc_13", "bc_29", "bc_34", "bc_97", "bc_5", "bc_11", "bc_1", "bc_27", "bc_138", "bc_115", "h_183", "bc_98", "bc_161", "h_45", "h_56", "h_39", "h_46", "h_41", "h_186", "h_184", "h_67", "h_180", "h_65", "h_185", "h_37", "h_38", "h_52", "h_36", "h_63", "h_176", "h_207", "h_60", "h_193", "h_35", "h_197", "h_182", "h_194", "h_196", "h_201", "h_69", "h_204", "h_212", "h_187", "h_188", "h_208", "h_66", "h_190", "h_198", "bc_100", "h_211", "h_40", "h_199", "h_59", "h_179", "h_50", "h_62", "bc_157", "h_205", "h_57", "h_213", "h_58", "h_189", "h_210", "h_48", "h_61", "h_200", "h_51", "h_44", "h_191", "h_195", "h_192", "h_209"], "y": ["Folate metabolism_dif", "Butanoate metabolism_dif", "Eicosanoid metabolism_dif", "Glutathione metabolism_dif", "Glycine, serine, alanine and threonine metabolism_dif", "Urea cycle_dif", "Pentose phosphate pathway_dif", "Pyrimidine catabolism_dif", "CoA synthesis_dif", "Vitamin C metabolism_dif", "Fatty acid oxidation_dif", "Glutamate metabolism_dif", "Tyrosine metabolism_dif", "Citric acid cycle_dif", "Bile acid synthesis_dif", "Arginine and Proline Metabolism_dif", "Methionine and cysteine metabolism_dif", "Glycolysis/gluconeogenesis_dif", "CoA catabolism_dif", "Taurine and hypotaurine metabolism_dif", "Alanine and aspartate metabolism_dif", "Nucleotide interconversion_dif"], "type": "heatmap", "z": [[-2618.8312258787396, -2618.83122587833, -1118.8312258812837, -2618.83122587888, -1567.5621263409769, -2110.1701649809297, -2618.831225878418, -2618.8312258807164, -795.9433892547831, -1470.2509727973622, -1620.5423428892789, -1935.9327466990583, -180.45720521958606, -2618.8312258784, -560.1965475207128, -2465.918816596402, -1357.7150097614608, -67.7013208343106, -947.7019261460455, -2618.831225878434, -1514.0470131643897, -1553.9247992492, -2042.3044371167266, -1680.1741519841646, -1545.1367976225783, 2846.3338853087243, -103.90684301445754, 575.1276909059687, -162.53445037743802, 1204.576050077213, 2181.168774120795, 1496.8823458555753, -2278.5828012626544, -2026.2694468754337, -1554.2312709575974, -2618.831225878863, -1539.0420393578854, -1461.2982487523752, -1489.3076408998204, 225.39720668633638, -281.0386819936375, 13.549890116478252, -614.0640161103911, -1264.2277955081531, -883.2552825125401, -608.2625201912081, -1489.5979242526491, -1203.9996528674806, -1248.9451633050114, ...

# %%
df= pd.DataFrame().from_records(X_pre)
pathways = np.array(df.keys())
data_array = df.values
labels = y

# %%
import plotly.plotly as py 
from plotly.graph_objs import *  
from plotly import figure_factory as ff
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

from scipy.cluster.hierarchy import linkage

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import plotly.plotly as py
from plotly.graph_objs import *
import plotly.figure_factory as FF

import numpy as np
from scipy.spatial.distance import pdist, squareform

figure = FF.create_dendrogram(data_array, orientation='bottom', labels=labels)
for i in range(len(figure['data'])):
    figure['data'][i]['yaxis'] = 'y2'

dendro_side = FF.create_dendrogram(data_array.T, orientation='right')
for i in range(len(dendro_side['data'])):
    dendro_side['data'][i]['xaxis'] = 'x2'

figure['data'].extend(dendro_side['data'])

dendro_leaves = dendro_side['layout']['yaxis']['ticktext']
dendro_leaves = list(map(int, dendro_leaves))
data_dist = pdist(data_array)
heat_data = squareform(data_dist)
heat_data = heat_data[dendro_leaves,:]
heat_data = heat_data[:,dendro_leaves]

heatmap = Data([
    Heatmap(
        x = dendro_leaves,
        y = dendro_leaves,
        z = heat_data,
        colorscale = 'YIGnBu'
    )
])

heatmap[0]['x'] = figure['layout']['xaxis']['tickvals']
heatmap[0]['y'] = dendro_side['layout']['yaxis']['tickvals']

# Add Heatmap Data to Figure
figure['data'].extend(Data(heatmap))

# Edit Layout
figure['layout'].update({'width':800, 'height':800,
                         'showlegend':False, 'hovermode': 'closest',
                         })
# Edit xaxis
figure['layout']['xaxis'].update({'domain': [.15, 1],
                                  'mirror': False,
                                  'showgrid': False,
                                  'showline': False,
                                  'zeroline': False,
                                  'ticks':""})
# Edit xaxis2
figure['layout'].update({'xaxis2': {'domain': [0, .15],
                                   'mirror': False,
                                   'showgrid': False,
                                   'showline': False,
                                   'zeroline': False,
                                   'showticklabels': False,
                                   'ticks':""}})

# Edit yaxis
figure['layout']['yaxis'].update({'domain': [0, .85],
                                  'mirror': False,
                                  'showgrid': False,
                                  'showline': False,
                                  'zeroline': False,
                                  'showticklabels': False,
                                  'ticks': ""})
# Edit yaxis2
figure['layout'].update({'yaxis2':{'domain':[.825, .975],
                                   'mirror': False,
                                   'showgrid': False,
                                   'showline': False,
                                   'zeroline': False,
                                   'showticklabels': False,
                                   'ticks':""}})

# Plot!
py.iplot(figure, filename='dendrogram_with_heatmap')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~muhammedhasan/10.embed" height="800px" width="800px"></iframe>

# %%
figure = ff.create_dendrogram(data_array, orientation='bottom', labels=labels,
                              linkagefun=lambda x: linkage(data_array, 'complete', metric='correlation'))
for i in range(len(figure['data'])):
    figure['data'][i]['yaxis'] = 'y2'

dendro_side = ff.create_dendrogram(data_array, orientation='right',
                                   linkagefun=lambda x: linkage(data_array, 'complete', metric='correlation'))

for i in range(len(dendro_side['data'])):
    dendro_side['data'][i]['xaxis'] = 'x2'

# Add Side Dendrogram Data to Figure
figure['data'].extend(dendro_side['data'])

# Create Heatmap
dendro_leaves = dendro_side['layout']['yaxis']['ticktext']
dendro_leaves = list(map(int, dendro_leaves))
data_dist = pdist(data_array)
heat_data = squareform(data_dist)
heat_data = heat_data[dendro_leaves,:]
heat_data = heat_data[:,dendro_leaves]

heatmap = Data([
    Heatmap(
        x = dendro_leaves, 
        y = dendro_leaves,
        z = heat_data,    
        colorscale = [[0.0, 'rgb(165,0,38)'], [0.1111111111111111, 'rgb(215,48,39)'], [0.2222222222222222, 'rgb(244,109,67)'], [0.3333333333333333, 'rgb(253,174,97)'], [0.4444444444444444, 'rgb(254,224,144)'], [0.5555555555555556, 'rgb(224,243,248)'], [0.6666666666666666, 'rgb(171,217,233)'], [0.7777777777777778, 'rgb(116,173,209)'], [0.8888888888888888, 'rgb(69,117,180)'], [1.0, 'rgb(49,54,149)']]
    )
])

heatmap[0]['x'] = figure['layout']['xaxis']['tickvals']
heatmap[0]['y'] = dendro_side['layout']['yaxis']['tickvals']

# Add Heatmap Data to Figure
figure['data'].extend(Data(heatmap))

# Edit Layout
figure['layout'].update({'width':800, 'height':800,
                         'showlegend':False, 'hovermode': 'closest',
                         })
# Edit xaxis
figure['layout']['xaxis'].update({'domain': [.15, 1],
                                  'mirror': False,
                                  'showgrid': False,
                                  'showline': False,
                                  'zeroline': False,
                                  'ticks':""})
# Edit xaxis2
figure['layout'].update({'xaxis2': {'domain': [0, .15],
                                   'mirror': False,
                                   'showgrid': False,
                                   'showline': False,
                                   'zeroline': False,
                                   'showticklabels': False,
                                   'ticks':""}})

# Edit yaxis
figure['layout']['yaxis'].update({'domain': [0, .85],
                                  'mirror': False,
                                  'showgrid': False,
                                  'showline': False,
                                  'zeroline': False,
                                  'showticklabels': False,
                                  'ticks': ""})
# Edit yaxis2
figure['layout'].update({'yaxis2':{'domain':[.825, .975],
                                   'mirror': False,
                                   'showgrid': False,
                                   'showline': False,
                                   'zeroline': False,
                                   'showticklabels': False,
                                   'ticks':""}})

# Plot!
iplot(figure, filename='heatmap_subject.html')
# Out:
# <div id="b5eea27b-a419-48a1-bbd9-a021a9751a4b" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b5eea27b-a419-48a1-bbd9-a021a9751a4b", [{"y": [0.0, 0.000589315359216025, 0.000589315359216025, 0.0], "x": [15.0, 15.0, 25.0, 25.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.0010883717983508623, 0.0010883717983508623, 0.000589315359216025], "x": [5.0, 5.0, 20.0, 20.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.03168538231867679, 0.03168538231867679, 0.0], "x": [35.0, 35.0, 45.0, 45.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0010883717983508623, 0.189824860662398, 0.189824860662398, 0.03168538231867679], "x": [12.5, 12.5, 40.0, 40.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.1164538710595554, 0.1164538710595554, 0.0], "x": [65.0, 65.0, 75.0, 75.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.35459084739222513, 0.35459084739222513, 0.1164538710595554], "x": [55.0, 55.0, 70.0, 70.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.189824860662398, 0.4824860291260925, 0.4824860291260925, 0.35459084739222513], "x": [26.25, 26.25, 62.5, 62.5], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.02025323841382143, 0.02025323841382143, 0.0], "x": [85.0, 85.0, 95.0, 95.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.03355552827180297, 0.03355552827180297, 0.0], "x": [115.0, 115.0, 125.0, 125.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.11351283492630038, 0.11351283492630038, 0.03355552827180297], "x": [105.0, 105.0, 120.0, 120.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.02025323841382143, 0.21187972847124503, 0.21187972847124503, 0.11351283492630038], "x": [90.0, 90.0, 112.5, 112.5], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.024923784726630926, 0.024923784726630926, 0.0], "x": [145.0, 145.0, 155.0, 155.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.07402946964664159, 0.07402946964664159, 0.024923784726630926], "x": [135.0, 135.0, 150.0, 150.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 6.244513362574367e-05, 6.244513362574367e-05, 0.0], "x": [205.0, 205.0, 215.0, 215.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.0022168570046920966, 0.0022168570046920966, 6.244513362574367e-05], "x": [195.0, 195.0, 210.0, 210.0], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.008311447705526165, 0.008311447705526165, 0.0022168570046920966], "x": [185.0, 185.0, 202.5, 202.5], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.020440186865687493, 0.020440186865687493, 0.008311447705526165], "x": [175.0, 175.0, 193.75, 193.75], "xaxis": "x", "type": "scatter", "yaxis": "y2", "mode": "lines", "marker": {"color": "rgb(61,153,112)"}}, {"y": [0.0, 0.002418326115031677, 0.002418326115031677, 0.0], "x ...
