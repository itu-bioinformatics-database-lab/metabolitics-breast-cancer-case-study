# %%
import os
os.chdir(os.path.join(os.getcwd(),'..'))

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:.2g}'.format)

# %%
from services import DataReader

X_biomass, y = DataReader().read_analyze_solution('biomass_maximization_fba_results', gz=False)
X_biomass = [{k + '_bio': v for k, v in x.items()} for x in X_biomass]

# %%
from preprocessing import DynamicPreprocessing

pre = DynamicPreprocessing(['pathway-scoring', 'transport-elimination'])
X_biomass_pathways = pre.fit_transform(X_biomass, y)

# %%
from services import feature_importance_anova

df_biomass_pathways = feature_importance_anova(X_biomass_pathways, y)
df_biomass_pathways
# Out:
# labels                                                   bc        h       F  \
# Methionine and cysteine metabolism_bio                   95       32 1.1e+02
# CoA catabolism_bio                                  2.3e+02       57   1e+02
# Taurine and hypotaurine metabolism_bio              3.9e+02  1.1e+02      97
# Biotin metabolism_bio                               3.8e+02  1.7e+02      83
# Glycerophospholipid metabolism_bio                      -26     -1.4      61
# Nucleotide interconversion_bio                           19      6.1      39
# Arginine and Proline Metabolism_bio                 1.4e+02       89      37
# Butanoate metabolism_bio                           -3.2e+02 -2.3e+02      37
# Purine synthesis_bio                                     12  1.2e+02      34
# Glutamate metabolism_bio                           -1.7e+02   -1e+02      31
# Sphingolipid metabolism_bio                              11       19      20
# Tyrosine metabolism_bio                                -1.9     0.41      17
# ROS detoxification_bio                              2.2e+02  2.5e+02      16
# Pentose phosphate pathway_bio                         1e+02  1.5e+02      16
# Hyaluronan metabolism_bio                               4.9       32      15
# Aminosugar metabolism_bio                               3.4       15      14
# Glycolysis/gluconeogenesis_bio                           31       15      13
# Eicosanoid metabolism_bio                               2.3      5.4      12
# Purine catabolism_bio                                    50       67      11
# Fatty acid synthesis_bio                                9.4      4.2      11
# Pyruvate metabolism_bio                                  71  1.1e+02      11
# Vitamin C metabolism_bio                                  6       20      10
# Glutathione metabolism_bio                              3.9       29      10
# Phosphatidylinositol phosphate metabolism_bio          -3.8    -0.13     9.6
# Alanine and aspartate metabolism_bio                1.6e+02  1.1e+02     8.9
# CoA synthesis_bio                                       6.6       15     7.5
# Galactose metabolism_bio                                 25       42     6.4
# Glycine, serine, alanine and threonine metaboli...  1.4e+02  1.7e+02     6.3
# Vitamin D metabolism_bio                               0.33      1.4     6.3
# Cholesterol metabolism_bio                               29       34     5.7
# Histidine metabolism_bio                                1.6      8.3     5.5
# N-glycan synthesis_bio                                 0.14      1.7     5.1
# N-glycan degradation_bio                                0.1      1.2     4.6
# Vitamin A metabolism_bio                                1.2      2.9     4.1
# Folate metabolism_bio                                  -7.5     0.52     3.8
# Citric acid cycle_bio                                   -53      -85     3.7
# Squalene and cholesterol synthesis_bio              1.5e+02  2.2e+02     2.6
# NAD metabolism_bio                                       47       60     2.5
# Cysteine Metabolism_bio                            -3.7e+02 -4.1e+02     2.4
# R group synthesis_bio                               1.6e+02  1.8e+02     2.4
# Propanoate metabolism_bio                                15       25     2.4
# Thiamine metabolism_bio                                  12      5.8     2.3
# Fatty acid oxidation_bio                                7.9      9.1       2
# Oxidative phosphorylation_bio                       4.4e+02  4.2e+02     1.9
# Glycosphingolipid metabolism_bio                      0.076     0.32     1.8
# Pyrimidine synthesis_bio                                -37      -32     1.7
# D-alanine metabolism_bio                            3.3e+02  3.3e+02     1.6
# Fructose and mannose metabolism_bio                     9.5       13     1.1
# Starch and sucrose metabolism_bio                       -11     -6.6     1.1
# Valine, leucine, and isoleucine metabolism_bio           63       76    0.95
# Heme synthesis_bio                                      3.1      4.7     0.9
# Pyrimidine catabolism_bio                              -3.9      -10    0.54
# Lysine metabolism_bio                                    77       65    0.51
# Heme degradation_bio                                    6.7        9    0.43
# Glyoxylate and dicarboxylate metabolism_bio         2.1e+02  1.9e+02    0.35
# Miscellaneous_bio                                        37       36    0.31
# Bile acid synthesis_bio                                  16       17    0.25
# Triacylglycerol synthesis_bio                            29       31    0.22
# beta-Alanine metabolism_bio                              65       60    0.22
# Vitamin B2 metabolism_bio                              -7.1     -9.6     0.2
# Steroid metabolism_bio                                0.075   -0.061   0.093
# Urea cycle_bio                                           24       26   0.099
# Nucleotide salvage pathway_bio                           98       92   0.097
# Ubiquinone synthesis_bio                                 19       20   0.055
# Tryptophan metabolism_bio                              0.65     0.92   0.033
# Inositol phosphate metabolism_bio                       4.9        5  0.0078
#
# labels                                                pval
# Methionine and cysteine metabolism_bio             7.5e-20
# CoA catabolism_bio                                 5.7e-18
# Taurine and hypotaurine metabolism_bio             1.1e-17
# Biotin metabolism_bio                              1.1e-15
# Glycerophospholipid metabolism_bio                 3.1e-12
# Nucleotide interconversion_bio                     2.1e-08
# Arginine and Proline Metabolism_bio                4.2e-08
# Butanoate metabolism_bio                           4.3e-08
# Purine synthesis_bio                               1.6e-07
# Glutamate metabolism_bio                           6.3e-07
# Sphingolipid metabolism_bio                        6.5e-05
# Tyrosine metabolism_bio                            0.00024
# ROS detoxification_bio                             0.00045
# Pentose phosphate pathway_bio                      0.00049
# Hyaluronan metabolism_bio                          0.00079
# Aminosugar metabolism_bio                          0.00085
# Glycolysis/gluconeogenesis_bio                      0.0019
# Eicosanoid metabolism_bio                           0.0028
# Purine catabolism_bio                               0.0034
# Fatty acid synthesis_bio                            0.0037
# Pyruvate metabolism_bio                             0.0043
# Vitamin C metabolism_bio                            0.0046
# Glutathione metabolism_bio                          0.0046
# Phosphatidylinositol phosphate metabolism_bio        0.006
# Alanine and aspartate metabolism_bio                0.0086
# CoA synthesis_bio                                    0.017
# Galactose metabolism_bio                             0.029
# Glycine, serine, alanine and threonine metaboli...    0.03
# Vitamin D metabolism_bio                              0.03
# Cholesterol metabolism_bio                            0.04
# Histidine metabolism_bio                             0.041
# N-glycan synthesis_bio                               0.051
# N-glycan degradation_bio                             0.068
# Vitamin A metabolism_bio                             0.085
# Folate metabolism_bio                                0.099
# Citric acid cycle_bio                                  0.1
# Squalene and cholesterol synthesis_bio                 0.2
# NAD metabolism_bio                                     0.2
# Cysteine Metabolism_bio                                0.2
# R group synthesis_bio                                  0.2
# Propanoate metabolism_bio                              0.2
# Thiamine metabolism_bio                                0.2
# Fatty acid oxidation_bio                              0.25
# Oxidative phosphorylation_bio                         0.26
# Glycosphingolipid metabolism_bio                      0.27
# Pyrimidine synthesis_bio                              0.27
# D-alanine metabolism_bio                               0.3
# Fructose and mannose metabolism_bio                    0.4
# Starch and sucrose metabolism_bio                      0.4
# Valine, leucine, and isoleucine metabolism_bio        0.44
# Heme synthesis_bio                                    0.44
# Pyrimidine catabolism_bio                             0.59
# Lysine metabolism_bio                                 0.59
# Heme degradation_bio                                  0.62
# Glyoxylate and dicarboxylate metabolism_bio           0.67
# Miscellaneous_bio                                     0.68
# Bile acid synthesis_bio                               0.72
# Triacylglycerol synthesis_bio                         0.72
# beta-Alanine metabolism_bio                           0.72
# Vitamin B2 metabolism_bio                             0.72
# Steroid metabolism_bio                                 0.8
# Urea cycle_bio                                         0.8
# Nucleotide salvage pathway_bio                         0.8
# Ubiquinone synthesis_bio                              0.84
# Tryptophan metabolism_bio                             0.87
# Inositol phosphate metabolism_bio                     0.93

# %%
X, y = DataReader().read_analyze_solution('bc_averaging_disease_analysis#k=0')

pre = DynamicPreprocessing(['flux-diff', 'pathway-scoring', 'transport-elimination'])
X_pathways = pre.fit_transform(X, y)
df_pathways = feature_importance_anova(X_pathways, y)

# %%
[ in df_biomass_pathways[df_biomass_pathways.pval < 0.05].index]
# Out:
# ['Methionine and cysteine metabolism',
#  'CoA catabolism',
#  'Taurine and hypotaurine metabolism',
#  'Biotin metabolism',
#  'Glycerophospholipid metabolism',
#  'Nucleotide interconversion',
#  'Arginine and Proline Metabolism',
#  'Butanoate metabolism',
#  'Purine synthesis',
#  'Glutamate metabolism',
#  'Sphingolipid metabolism',
#  'Tyrosine metabolism',
#  'ROS detoxification',
#  'Pentose phosphate pathway',
#  'Hyaluronan metabolism',
#  'Aminosugar metabolism',
#  'Glycolysis/gluconeogenesis',
#  'Eicosanoid metabolism',
#  'Purine catabolism',
#  'Fatty acid synthesis',
#  'Pyruvate metabolism',
#  'Vitamin C metabolism',
#  'Glutathione metabolism',
#  'Phosphatidylinositol phosphate metabolism',
#  'Alanine and aspartate metabolism',
#  'CoA synthesis',
#  'Galactose metabolism',
#  'Glycine, serine, alanine and threonine metabolism',
#  'Vitamin D metabolism',
#  'Cholesterol metabolism',
#  'Histidine metabolism']

# %%
m_set = set(p[:-4] for p in df_pathways[df_pathways.pval < 0.05].index) 
bio_set = set(p[:-4] for p in df_biomass_pathways[df_biomass_pathways.pval < 0.05].index)

print('Only in metabolitics: %d' % len(m_set - bio_set))
print(m_set - bio_set)
print('Only in biomass: %d' % len(bio_set - m_set))
print(bio_set - m_set)
print('Both: %d' % len(bio_set & m_set))
# Out:
# Only in metabolitics: 8
# {'Bile acid synthesis', 'Fatty acid oxidation', 'Inositol phosphate metabolism', 'Tetrahydrobiopterin metabolism', 'Tryptophan metabolism', 'Squalene and cholesterol synthesis', 'Glyoxylate and dicarboxylate metabolism', 'Urea cycle'}
# Only in biomass: 7
# {'Glutathione metabolism', 'CoA synthesis', 'Biotin metabolism', 'Cholesterol metabolism', 'Vitamin D metabolism', 'Fatty acid synthesis', 'Vitamin C metabolism'}
# Both: 24

# %% [markdown]
# ## Fisher Exact Test

# %%
from services import DataReader

X, y = DataReader().read_analyze_solution('bc_averaging_disease_analysis#k=0')

# %%
from services import fisher_exact_test_for_pathway
from preprocessing import DynamicPreprocessing

X_dif = DynamicPreprocessing(['flux-diff']).fit_transform(X, y)

# %%
pd.Series({k : v[1] for k, v in fisher_exact_test_for_pathway(X_dif, y).items() if k}).sort_values()
# Out:
# Fatty acid oxidation                                2.9e-36
# Nucleotide interconversion                          5.3e-15
# Fatty acid synthesis                                1.2e-09
# Pyrimidine catabolism                               2.4e-05
# Lysine metabolism                                   7.8e-05
# Bile acid synthesis                                 0.00037
# Glycine, serine, alanine and threonine metabolism   0.00041
# Sphingolipid metabolism                             0.00069
# Oxidative phosphorylation                           0.00071
# Heme synthesis                                      0.00071
# Arginine and Proline Metabolism                      0.0023
# Valine, leucine, and isoleucine metabolism           0.0024
# Alanine and aspartate metabolism                     0.0024
# Pyruvate metabolism                                  0.0046
# Triacylglycerol synthesis                            0.0052
# Urea cycle                                           0.0063
# Eicosanoid metabolism                                0.0074
# Citric acid cycle                                     0.008
# Pyrimidine synthesis                                  0.008
# Folate metabolism                                     0.013
# Glycerophospholipid metabolism                        0.013
# Vitamin A metabolism                                  0.013
# Methionine and cysteine metabolism                    0.025
# Glycolysis/gluconeogenesis                            0.026
# Taurine and hypotaurine metabolism                    0.026
# Cholesterol metabolism                                0.027
# Miscellaneous                                         0.029
# CoA synthesis                                         0.044
# Pentose phosphate pathway                             0.054
# Purine catabolism                                     0.054
# Tryptophan metabolism                                 0.058
# Glutathione metabolism                                  0.1
# Fructose and mannose metabolism                        0.11
# NAD metabolism                                         0.11
# CoA catabolism                                         0.18
# Steroid metabolism                                     0.25
# ROS detoxification                                     0.46
# beta-Alanine metabolism                                0.48
# Galactose metabolism                                   0.48
# Glyoxylate and dicarboxylate metabolism                0.48
# Aminosugar metabolism                                  0.49
# Vitamin E metabolism                                      1
# Androgen and estrogen synthesis and metabolism            1
# Vitamin D metabolism                                      1
# Vitamin C metabolism                                      1
# R group synthesis                                         1
# Vitamin B6 metabolism                                     1
# Vitamin B2 metabolism                                     1
# Selenoamino acid metabolism                               1
# Purine synthesis                                          1
# Vitamin B12 metabolism                                    1
# Squalene and cholesterol synthesis                        1
# Starch and sucrose metabolism                             1
# Alkaloid synthesis                                        1
# Stilbene, coumarine and lignin synthesis                  1
# Tetrahydrobiopterin metabolism                            1
# Thiamine metabolism                                       1
# Tyrosine metabolism                                       1
# Ubiquinone synthesis                                      1
# Chondroitin synthesis                                     1
# Phosphatidylinositol phosphate metabolism                 1
# Cysteine Metabolism                                       1
# Cytochrome metabolism                                     1
# D-alanine metabolism                                      1
# Dietary fiber binding                                     1
# C5-branched dibasic acid metabolism                       1
# Glutamate metabolism                                      1
# Butanoate metabolism                                      1
# Glycosphingolipid metabolism                              1
# Heme degradation                                          1
# Blood group synthesis                                     1
# Heparan sulfate degradation                               1
# Histidine metabolism                                      1
# Hyaluronan metabolism                                     1
# Propanoate metabolism                                     1
# Inositol phosphate metabolism                             1
# Keratan sulfate synthesis                                 1
# Limonene and pinene degradation                           1
# Linoleate metabolism                                      1
# Lipoate metabolism                                        1
# Xenobiotics metabolism                                    1
# N-glycan degradation                                      1
# N-glycan synthesis                                        1
# Chondroitin sulfate degradation                           1
# Nucleotide salvage pathway                                1
# Nucleotide sugar metabolism                               1
# O-glycan synthesis                                        1
# Arachidonic acid metabolism                               1
# Phenylalanine metabolism                                  1
# Keratan sulfate degradation                               1
# Biotin metabolism                                         1
# dtype: float64

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction import DictVectorizer
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedKFold, GroupKFold

from preprocessing import PathwayReactionEnrichment

pipe = Pipeline([
    ('df', DynamicPreprocessing(['flux-diff'])),
    ('enrichment', PathwayReactionEnrichment()),
    ('vect', DictVectorizer(sparse=False)),
    ('pca', PCA()),
    ('clf', LogisticRegression(C=0.3e-6, random_state=43))
])

kf = StratifiedKFold(n_splits=10, random_state=43)

scores = cross_val_score(pipe, X, y, cv=kf, scoring='f1_micro')
print('kfold test: %s' % scores)
print('mean: %s' % scores.mean().round(3))
print('std: %s' % scores.std().round(3))
# Out:
# kfold test: [ 0.77272727  0.72727273  0.77272727  0.77272727  0.72727273  0.72727273
#   0.85714286  0.85714286  0.85        0.9       ]
# mean: 0.796
# std: 0.061
